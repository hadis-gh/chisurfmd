# %%
import numpy as np
import matplotlib.pyplot as plt

def readPositions(filename):
    data = np.loadtxt(filename)
    numSteps = data.shape[0]
    numParticles = data.shape[1] // 2
    positions = data.reshape(numSteps, numParticles, 2)
    return positions

positions = readPositions("/home/hadis/custom_vector/build/test/particlesPosMD.txt")
print("positions shape:", positions.shape)

fig, ax = plt.subplots()

for i in range(positions.shape[1]):
    ax.plot(positions[:, i, 0], positions[:, i, 1], 'o-')

ax.set_xlim(np.min(positions[:, :, 0]), np.max(positions[:, :, 0]))
ax.set_ylim(np.min(positions[:, :, 1]), np.max(positions[:, :, 1]))

plt.show()
