# %%
# path of particles for Symplectic Euler VS Velocity Verlet method

import numpy as np
import matplotlib.pyplot as plt

def readPositions(filename):
    data = np.loadtxt(filename)[:, 1:]
    numSteps = data.shape[0]
    numParticles = data.shape[1] // 2
    positions = data.reshape(numSteps, numParticles, 2)
    return positions

path_euler = "/home/hadis/custom_vector/buildParticleOriented/buildVS/jan7_dotLong_COMang_diffSeed2/N_particle_PosMD.dat"
pos_euler = readPositions(path_euler)

path_vv = "/home/hadis/custom_vector/buildParticleOriented/buildVS/jan7_dotLong_COMang_diffSeed3/N_particle_PosMD.dat"
pos_vv = readPositions(path_vv)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1.scatter(pos_euler[0, :, 0], pos_euler[0, :, 1], label='Initial Positions', color='blue')
ax1.scatter(pos_euler[-1, :, 0], pos_euler[-1, :, 1], label='Final Positions', marker='x', color='red')
ax1.set_title('Initial and final positions', fontsize = 15)
ax1.set_ylabel('Euler Integration', fontsize = 15)
ax1.legend()

for i in range(pos_euler.shape[1]):
    ax2.plot(pos_euler[:, i, 0], pos_euler[:, i, 1], lw=.5)
ax2.set_title('particles path', fontsize = 15)

ax3.scatter(pos_vv[0, :, 0], pos_vv[0, :, 1], label='Initial Positions', color='blue')
ax3.scatter(pos_vv[-1, :, 0], pos_vv[-1, :, 1], label='Final Positions', marker='x', color='red')
ax3.set_ylabel('Velocity Verlet Integration', fontsize = 15)
# ax3.set_ylim(np.min(pos_vv[0, :, 1]), np.max(pos_vv[0, :, 1]))
# ax3.set_xlim(np.min(pos_vv[0, :, 0]), np.max(pos_vv[0, :, 0]))
ax3.legend()

for i in range(pos_vv.shape[1]):
    ax4.plot(pos_vv[:, i, 0], pos_vv[:, i, 1], lw=.5)
# ax4.set_ylim(np.min(pos_vv[0, :, 1]), np.max(pos_vv[0, :, 1]))
# ax4.set_xlim(np.min(pos_vv[0, :, 0]), np.max(pos_vv[0, :, 0]))

# %%
# energy of system for Euler VS Velocity Verlet method

import numpy as np
import matplotlib.pyplot as plt

kinetic_euler = np.sum(np.loadtxt('/home/hadis/custom_vector/build/test/euler/N_particle_KineticEnergyMD.dat'), axis = 1)
potential_euler = np.sum(np.loadtxt('/home/hadis/custom_vector/build/test/euler/N_particle_PotentialEnergyMD.dat'), axis = 1)
total_euler = kinetic_euler + potential_euler

kinetic_vv = np.sum(np.loadtxt('/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_KineticEnergyMD.dat'), axis = 1)
potential_vv = np.sum(np.loadtxt('/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_PotentialEnergyMD.dat'), axis = 1)
total_vv = kinetic_vv + potential_vv

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 18))

ax1.plot(kinetic_euler, label=f'Euler')
ax1.plot(kinetic_vv, label=f'Velocity Verlet')
ax1.set_xlabel('Time')
ax1.set_ylabel('Energy')
ax1.set_title('Kinetic Energy of system', fontsize = 15)
ax1.legend()
ax1.grid()

ax2.plot(potential_euler, label=f'Euler')
ax2.plot(potential_vv, label=f'Velocity Verlet')
ax2.set_xlabel('Time')
ax2.set_ylabel('Energy')
ax2.set_title('Potential Energy of system', fontsize = 15)
ax2.legend()
ax2.grid()

ax3.plot(total_euler, label=f'Euler')
ax3.plot(total_vv, label=f'Velocity Verlet')
ax3.set_xlabel('Time')
ax3.set_ylabel('Energy')
ax3.set_title('Total Energy of system', fontsize = 15)
ax3.legend()
ax3.grid()

# %%
# comparing various dt for double

import numpy as np
import matplotlib.pyplot as plt

time_steps = [0.0001, 0.001, 0.01, 0.1]
# time_steps = [0.0001, 0.001, 0.01, 0.1, 1]

kinetic_vv = []
potential_vv = []
total_vv = []

for i in time_steps:
    kinetic_vv_i = np.sum(np.loadtxt(f'/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_KineticEnergyMD_{i}.dat'), axis=1)
    potential_vv_i = np.sum(np.loadtxt(f'/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_PotentialEnergyMD_{i}.dat'), axis=1)
    total_vv_i = kinetic_vv_i + potential_vv_i

    kinetic_vv.append(kinetic_vv_i)
    potential_vv.append(potential_vv_i)
    total_vv.append(total_vv_i)

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 15))

for i, dt in enumerate(time_steps):
    ax1.plot(kinetic_vv[i], label=f'dt = {dt}')
ax1.set_xlabel('Time')
ax1.set_ylabel('Energy')
ax1.set_title('Kinetic Energy of System', fontsize=15)
ax1.legend()
ax1.grid()

for i, dt in enumerate(time_steps):
    ax2.plot(potential_vv[i], label=f'dt = {dt}')
ax2.set_xlabel('Time')
ax2.set_ylabel('Energy')
ax2.set_title('Potential Energy of System', fontsize=15)
ax2.legend()
ax2.grid()

for i, dt in enumerate(time_steps):
    ax3.plot(total_vv[i], label=f'dt = {dt}')
ax3.set_xlabel('Time')
ax3.set_ylabel('Energy')
ax3.set_title('Total Energy of System', fontsize=15)
ax3.legend()
ax3.grid()

plt.tight_layout()
plt.show()

# %%
# comparing various dt for float

import numpy as np
import matplotlib.pyplot as plt

time_steps = [0.0001, 0.001, 0.01, 0.1]
# time_steps = [0.0001, 0.001, 0.01, 0.1, 1]

kinetic_vv = []
potential_vv = []
total_vv = []

for i in time_steps:
    kinetic_vv_i = np.sum(np.loadtxt(f'/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_KineticEnergyMD_{i}.dat'), axis=1)
    potential_vv_i = np.sum(np.loadtxt(f'/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_PotentialEnergyMD_{i}.dat'), axis=1)
    total_vv_i = kinetic_vv_i + potential_vv_i

    kinetic_vv.append(kinetic_vv_i)
    potential_vv.append(potential_vv_i)
    total_vv.append(total_vv_i)

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 15))

for i, dt in enumerate(time_steps):
    ax1.plot(kinetic_vv[i], label=f'dt = {dt}')
ax1.set_xlabel('Time')
ax1.set_ylabel('Energy')
ax1.set_title('Kinetic Energy of System', fontsize=15)
ax1.legend()
ax1.grid()

for i, dt in enumerate(time_steps):
    ax2.plot(potential_vv[i], label=f'dt = {dt}')
ax2.set_xlabel('Time')
ax2.set_ylabel('Energy')
ax2.set_title('Potential Energy of System', fontsize=15)
ax2.legend()
ax2.grid()

for i, dt in enumerate(time_steps):
    ax3.plot(total_vv[i], label=f'dt = {dt}')
ax3.set_xlabel('Time')
ax3.set_ylabel('Energy')
ax3.set_title('Total Energy of System', fontsize=15)
ax3.legend()
ax3.grid()

plt.tight_layout()
plt.show()
