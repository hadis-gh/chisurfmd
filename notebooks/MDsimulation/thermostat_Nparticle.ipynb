# %%
import numpy as np
import matplotlib.pyplot as plt

def readPositions(filename):
    data = np.loadtxt(filename)[:, 1:]
    numSteps = data.shape[0]
    numParticles = data.shape[1] // 2
    positions = data.reshape(numSteps, numParticles, 2)
    return positions

def plotTraj(inputs, labels):
    num_plots = len(inputs)
    
    fig, axs = plt.subplots(num_plots, 2, figsize=(10, 5 * num_plots))
    
    if num_plots == 1:
        axs = np.array([axs])

    for j, fname in enumerate(inputs):
        label = labels[j]
        pos = readPositions(fname)

        axs[j][0].scatter(pos[0, :, 0], pos[0, :, 1], label='Initial Positions', color='blue')
        axs[j][0].scatter(pos[-1, :, 0], pos[-1, :, 1], label='Final Positions', marker='x', color='red')
        axs[j][0].set_title('Initial and final positions', fontsize = 15)
        axs[j][0].set_ylabel(label, fontsize = 15)
        axs[j][0].legend()

        for i in range(pos.shape[1]):
            axs[j][1].plot(pos[:, i, 0], pos[:, i, 1], lw=.5)
        axs[j][1].set_title(label, fontsize = 15)
    
    plt.tight_layout()
    plt.show()

# %%
 # path of particles for Symplectic Euler VS Velocity Verlet method

import numpy as np
import matplotlib.pyplot as plt

def readPositions(filename):
    data = np.loadtxt(filename)
    numSteps = data.shape[0]
    numParticles = data.shape[1] // 2
    positions = data.reshape(numSteps, numParticles, 2)
    return positions

def plotTraj(inputs, labels):

    fig, axs = plt.subplots(len(inputs), 2, figsize=(10, 15))

    for j, fname in enumerate(inputs):
        label = labels[j]
        pos = readPositions(fname)

        axs[j][0].scatter(pos[0, :, 0], pos[0, :, 1], label='Initial Positions', color='blue')
        axs[j][0].scatter(pos[-1, :, 0], pos[-1, :, 1], label='Final Positions', marker='x', color='red')
        axs[j][0].set_title('Initial and final positions', fontsize = 15)
        axs[j][0].set_ylabel(label, fontsize = 15)
        axs[j][0].legend()

        for i in range(pos.shape[1]):
            axs[j][1].plot(pos[:, i, 0], pos[:, i, 1], lw=.5)
        axs[j][1].set_title(label, fontsize = 15)

# %%
pathpattern = "/home/hadis/custom_vector/build/test/checkpointRestart/split/N_particle_PosMD_{}.dat"
runs = [1, 2, 3]
inputs = [pathpattern.format(x) for x in runs]
print(inputs)
plotTraj(inputs, runs)
# Out:
# ['/home/hadis/custom_vector/build/test/checkpointRestart/split/N_particle_PosMD_1.dat', '/home/hadis/custom_vector/build/test/checkpointRestart/split/N_particle_PosMD_2.dat', '/home/hadis/custom_vector/build/test/checkpointRestart/split/N_particle_PosMD_3.dat']

# %%
inputs = ["/home/hadis/custom_vector/build/test/N_particle_PosMD.dat"]
labels = ['Path']

plotTraj(inputs, labels)

# %%
inputs = ["/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_PosMD.dat",
    "/home/hadis/custom_vector/build/test/velocityVerlet/thermostat/velocityScaling/N_particle_PosMD.dat",
    "/home/hadis/custom_vector/build/test/velocityVerlet/thermostat/berendsen/N_particle_PosMD.dat",
    "/home/hadis/custom_vector/build/test/velocityVerlet/thermostat/andersen/N_particle_PosMD.dat"
]
labels = ['Without Thermostat',
'particles path(VV)', 'Velocity Scaling Thermostat(VV)', 'Berendsen Thermostat(VV)','Andersen Thermostat(VV)'
]

plotTraj(inputs, labels)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_704278/801957014.py in <module>
#       8 ]
#       9
# ---> 10 plotTraj(inputs, labels)
#
# /tmp/ipykernel_704278/181599460.py in plotTraj(inputs, labels)
#      19     for j, fname in enumerate(inputs):
#      20         label = labels[j]
# ---> 21         pos = readPositions(fname)
#      22
#      23         axs[j][0].scatter(pos[0, :, 0], pos[0, :, 1], label='Initial Positions', color='blue')
#
# /tmp/ipykernel_704278/181599460.py in readPositions(filename)
#       3
#       4 def readPositions(filename):
# ----> 5     data = np.loadtxt(filename)[:, 1:]
#       6     numSteps = data.shape[0]
#       7     numParticles = data.shape[1] // 2
#
# /usr/lib/python3/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_and_sum(file_path):
    data = np.loadtxt(file_path)
    return np.sum(data, axis=1)

def calculate_energies(base_path, subpath=""):
    kinetic = load_and_sum(f"{base_path}{subpath}N_particle_KineticEnergyMD.dat")
    potential = load_and_sum(f"{base_path}{subpath}N_particle_PotentialEnergyMD.dat")
    total = kinetic + potential
    return kinetic, potential, total

def plot_energy(ax, energies, labels, title):
    for j, energy in enumerate(energies):
        ax.plot(energy, label=labels[j])
    ax.set_xlabel("Time")
    ax.set_ylabel("Energy")
    ax.set_title(title, fontsize=15)
    ax.legend()
    ax.grid()

base_path = '/home/hadis/custom_vector/build/test/velocityVerlet/'

thermotypes_labels = ['no thermostat', 'velocity scaling thermostat', 'berendsen thermostat', 'andersen thermostat']
energies_labels = ['Kinetic Energy', 'Potential Energy', 'Total Energy']

energies = [
    calculate_energies(base_path),
    calculate_energies(base_path, 'thermostat/velocityScaling/'),
    calculate_energies(base_path, 'thermostat/berendsen/'),
    calculate_energies(base_path, 'thermostat/andersen/')
]

fig, ax = plt.subplots(3, 1, figsize=(10, 18))

for j, energy_label in enumerate(energies_labels):
    energy_data = [energy[j] for energy in energies]
    plot_energy(ax[j], energy_data, thermotypes_labels, energy_label)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_704278/993932530.py in <module>
#      27
#      28 energies = [
# ---> 29     calculate_energies(base_path),
#      30     calculate_energies(base_path, 'thermostat/velocityScaling/'),
#      31     calculate_energies(base_path, 'thermostat/berendsen/'),
#
# /tmp/ipykernel_704278/993932530.py in calculate_energies(base_path, subpath)
#       7
#       8 def calculate_energies(base_path, subpath=""):
# ----> 9     kinetic = load_and_sum(f"{base_path}{subpath}N_particle_KineticEnergyMD.dat")
#      10     potential = load_and_sum(f"{base_path}{subpath}N_particle_PotentialEnergyMD.dat")
#      11     total = kinetic + potential
#
# /tmp/ipykernel_704278/993932530.py in load_and_sum(file_path)
#       3
#       4 def load_and_sum(file_path):
# ----> 5     data = np.loadtxt(file_path)
# ...

# %%
ls = [np.array([1, 2]),
      np.array([3, 4]),
      np.array([5, 6]),
      np.array([7, 8])]

ls2 = np.array([np.array([1, 2]),
      np.array([3, 4]),
      np.array([5, 6]),
      np.array([7, 8])])

for i in range(len(ls)):
    print(ls[i][0])

lss = [el[0] for el in ls]

print (lss)

for el in ls:
    print(el[0])
# Out:
# 1
# 3
# 5
# 7
# [1, 3, 5, 7]
# 1
# 3
# 5
# 7

# %%
dat = np.loadtxt("/home/hadis/custom_vector/build/test/checkpointRestart/split/N_particle_NeighborsMD.dat")
plt.plot(dat)

# %%
pathpattern = "/home/hadis/custom_vector/build/test/checkpointRestart/full/N_particle_PosMD.dat"
runs = ["foo", "bar"]
inputs = [pathpattern.format(x) for x in runs]
print(inputs)
plotTraj(inputs, runs)
# Out:
# ['/home/hadis/custom_vector/build/test/checkpointRestart/full/N_particle_PosMD.dat', '/home/hadis/custom_vector/build/test/checkpointRestart/full/N_particle_PosMD.dat']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_704278/3841890823.py in <module>
#       3 inputs = [pathpattern.format(x) for x in runs]
#       4 print(inputs)
# ----> 5 plotTraj(inputs, runs)
#
# /tmp/ipykernel_704278/181599460.py in plotTraj(inputs, labels)
#      19     for j, fname in enumerate(inputs):
#      20         label = labels[j]
# ---> 21         pos = readPositions(fname)
#      22
#      23         axs[j][0].scatter(pos[0, :, 0], pos[0, :, 1], label='Initial Positions', color='blue')
#
# /tmp/ipykernel_704278/181599460.py in readPositions(filename)
#       6     numSteps = data.shape[0]
#       7     numParticles = data.shape[1] // 2
# ...
