# %%
import numpy as np
import matplotlib.pyplot as plt

def readPositions(filename):
    data = np.loadtxt(filename)
    numSteps = data.shape[0]
    numParticles = data.shape[1] // 2
    positions = data.reshape(numSteps, numParticles, 2)
    return positions

path_euler = "/home/hadis/custom_vector/build/test/euler/N_particle_PosMD.dat"
positions_euler = readPositions(path_euler)

path_vv = "/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_PosMD.dat"
positions_vv = readPositions(path_vv)

for positions in ( positions_euler, ):

    print("positions shape:", positions.shape)

    fig, ax = plt.subplots(1, 2)

    n = 2

    for i in range(positions.shape[1]):
        ax[0].plot(positions[:, i, 0], positions[:, i, 1], 'o', ms=.1)

    ax[1].scatter(positions[0, :, 0], positions[0, :, 1]) #, c=np.arange(positions.shape[1]))
    ax[1].scatter(positions[-1, :, 0], positions[-1, :, 1]) #, c=np.arange(positions.shape[1]))
    # ax.set_xlim(np.min(positions[:n, :, 0]), np.max(positions[:n, :, 0]))
    # ax.set_ylim(np.min(positions[:n, :, 1]), np.max(positions[:n, :, 1]))

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       9     return positions
#      11 path_euler = "/home/hadis/custom_vector/build/test/euler/N_particle_PosMD.dat"
# ---> 12 positions_euler = readPositions(path_euler)
#      14 path_vv = "/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_PosMD.dat"
#      15 positions_vv = readPositions(path_vv)
#
# Cell In[1], line 5, in readPositions(filename)
#       4 def readPositions(filename):
# ----> 5     data = np.loadtxt(filename)
#       6     numSteps = data.shape[0]
#       7     numParticles = data.shape[1] // 2
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /home/hadis/custom_vector/build/test/euler/N_particle_PosMD.dat not found.

# %%
import numpy as np
import matplotlib.pyplot as plt

energyK_euler = np.loadtxt("/home/hadis/custom_vector/build/test/euler/N_particle_KineticEnergyMD.dat")
energyK_vv = np.loadtxt("/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_KineticEnergyMD.dat")

total_KE_euler = np.sum(energyK_euler, axis = 1)
total_KE_vv = np.sum(energyK_vv, axis = 1)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

for i in range(energyK_vv.shape[1]):
    ax1.plot(energyK_euler[:, i], label=f'Particle {i+1}')

ax1.set_xlabel('Time')
ax1.set_ylabel('Energy')
ax1.set_title('Kinetic Energy of Each Particle')
ax1.legend()

ax2.plot(total_KE_vv, label=f'velocity verlet')
ax2.plot(total_KE_euler, label=f'euler')
ax2.set_xlabel('Time')
ax2.set_ylabel('Energy')
ax2.set_title('Kinetic Energy of system')
ax1.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 energyK_euler = np.loadtxt("/home/hadis/custom_vector/build/test/euler/N_particle_KineticEnergyMD.dat")
#       5 energyK_vv = np.loadtxt("/home/hadis/custom_vector/build/test/velocityVerlet/N_particle_KineticEnergyMD.dat")
#       7 total_KE_euler = np.sum(energyK_euler, axis = 1)
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /home/hadis/miniconda3/envs/visualMD/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /home/hadis/custom_vector/build/test/euler/N_particle_KineticEnergyMD.dat not found.
