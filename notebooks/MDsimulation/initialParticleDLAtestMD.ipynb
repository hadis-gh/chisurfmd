# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

def draw_circles(radius, areaL, centers, colors):
    fig, ax = plt.subplots()

    ax.set_xlim(0, areaL)
    ax.set_ylim(0, areaL)

    for i, center in enumerate(centers):
        circle = plt.Circle(center, radius, color=colors[i], fill=True)
        ax.add_artist(circle)

    ax.set_aspect('equal', adjustable='box')
    plt.show()

areaL = 10

particle = np.loadtxt("/home/hadis/custom_vector/build/test/initialParticlePositions.dat")
particle_radius = particle[0, 2]
particle_centers = particle[:, :2]

cmap = plt.cm.get_cmap('magma', len(particle_centers))
colors = [cmap(i) for i in range(len(particle_centers))]

draw_circles(particle_radius, areaL, particle_centers, colors)
particle

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

def draw_circles(radius, areaL, centers, colors):
    fig, ax = plt.subplots()

    ax.set_xlim(0, areaL)
    ax.set_ylim(0, areaL)

    for i, center in enumerate(centers):
        circle = plt.Circle(center, radius, color=colors[i], fill=True)
        ax.add_artist(circle)

    ax.set_aspect('equal', adjustable='box')
    plt.show()

areaL = 10

particle = np.loadtxt("/home/hadis/custom_vector/build/test/initialParticlePositions2.dat")
particle_radius = particle[0, 2]
particle_centers = particle[:, :2]

cmap = plt.cm.get_cmap('magma', len(particle_centers))
colors = [cmap(i) for i in range(len(particle_centers))]

draw_circles(particle_radius, areaL, particle_centers, colors)
particle
