# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

originPoint= (20 , 20)
movementDirection= (1 , 0)
length= 50
circlesRadius= 1

intersection= (22.8262 , 20)
NumberOfIteration= 0

circlesCenters= [(6.39423 , 25.1946), (46.5186 , 49.8854), (8.31397 , 12.7367), (41.0459 , 42.7523), (29.4985 , 34.6697), (12.2528 , 22.0403), (1.55751 , 2.65967), (4.86544 , 47.4292), (24.8507 , 13.1041), (5.13677 , 43.2297), (16.0827 , 19.4208), (28.6946 , 22.7253), (34.0685 , 2.88989), (45.6317 , 29.9842), (3.21049 , 24.6314), (23.7997 , 20.2287), (24.1581 , 48.9624), (28.108 , 49.8286), (12.4164 , 7.52818), (44.535 , 33.7293), (39.6701 , 30.7576), (45.4579 , 10.3871), (32.0005 , 27.5683), (48.9666 , 23.0624), (44.2521 , 20.4776), ]

fig, ax = plt.subplots()

ax.add_patch(patches.Rectangle((0, 0), length, length, fill=False))

ax.plot(*originPoint, 'go')

endPoint = (originPoint[0] + movementDirection[0], originPoint[1] + movementDirection[1])
ax.plot([originPoint[0], intersection[0]], [originPoint[1], intersection[1]], 'r-')

for center in circlesCenters:
    circle = patches.Circle(center, circle_radius, fill=False)
    ax.add_patch(circle)

ax.plot(*intersection, 'bx')

ax.set_xlim(0, length)
ax.set_ylim(0, length)

ax.set_aspect('equal', adjustable='box')

plt.show()
